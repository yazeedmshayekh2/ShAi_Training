# %% [markdown]
# # Seaborn Exercises
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on we will revisit this data. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
plot_1 = sns.JointGrid(data = titanic, x= titanic['fare'], y= titanic['age'], xlim=(-100,600))
plot_1.plot_joint(sns.scatterplot,  edgecolor=None, color='#698de2')
plot_1.ax_marg_x.hist(x= titanic['fare'], bins= 55, edgecolor="gray", color='#698de2')
plot_1.ax_marg_y.hist(titanic['age'], orientation="horizontal", bins= 19, edgecolor="gray", color='#698de2')
plot_1.ax_joint.set_yticks([0, 20, 40, 60, 80]);

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
hist_plot= sns.histplot(data= titanic, x="fare", bins=30, edgecolor="gray", color="#f87c7c")
plt.xlim([0,600])
plt.ylim([0,500])
plt.ylabel("");

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
box_plot = sns.boxplot(data=titanic, y= 'age', x='class', fliersize = 3.75, palette=(['#44a6c6', '#00A36C', '#FFAC1C']))
plt.ylim([0,80]);

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
from matplotlib.ticker import MultipleLocator
import matplotlib.ticker as ticker
fig = sns.swarmplot(data=titanic, y= 'age', x='class', palette=['#7eba7f', '#F28C28', '#8480f1'])
fig.yaxis.set_major_locator(MultipleLocator(20));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 15.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
bar_plot = sns.countplot(data= titanic, x= 'sex', palette=(['#5868dc', '#4b9b71']))
plt.ylim([0,600]);

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
heat_map = sns.heatmap(data = titanic.corr(), cmap="coolwarm");
heat_map.set_yticklabels(heat_map.get_yticklabels(), fontsize=9)
heat_map.set_xticklabels(heat_map.get_xticklabels(), rotation=0, horizontalalignment='center', fontsize=9)
heat_map.set_title(" titanic.corr()", fontsize=10);

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
import numpy as np 
plot_2 = sns.FacetGrid(data = titanic, col='sex')
plot_2.map_dataframe(sns.histplot, x="age", bins=10, edgecolor="black", color="#5868dc")
plt.ylim([0,120])
plt.xlim([0,83.979])
plot_2.set(xticks=np.arange(0,83.979,10));

# %% [markdown]
# ## #shAI Club
